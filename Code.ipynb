# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
act = pd.read_csv('dailyActivity_merged.csv')
act
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    4/12/2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391     5/8/2016       10686       8.110000         8.110000
# 936  8877689391     5/9/2016       20226      18.250000        18.250000
# 937  8877689391    5/10/2016       10733       8.150000         8.150000
# 938  8877689391    5/11/2016       21420      19.559999        19.559999
# 939  8877689391    5/12/2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
sleep = pd.read_csv('sleepDay_merged.csv')
sleep
# Out:
#              Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0    1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1    1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2    1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3    1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4    1503960366  4/17/2016 12:00:00 AM                  1                 700
# ..          ...                    ...                ...                 ...
# 408  8792009665  4/30/2016 12:00:00 AM                  1                 343
# 409  8792009665   5/1/2016 12:00:00 AM                  1                 503
# 410  8792009665   5/2/2016 12:00:00 AM                  1                 415
# 411  8792009665   5/3/2016 12:00:00 AM                  1                 516
# 412  8792009665   5/4/2016 12:00:00 AM                  1                 439
#
#      TotalTimeInBed
# ...

# %%
weight = pd.read_csv('weightLogInfo_merged.csv')
weight
# Out:
#             Id                   Date    WeightKg  WeightPounds   Fat  \
# 0   1503960366   5/2/2016 11:59:59 PM   52.599998    115.963147  22.0
# 1   1503960366   5/3/2016 11:59:59 PM   52.599998    115.963147   NaN
# 2   1927972279   4/13/2016 1:08:52 AM  133.500000    294.317120   NaN
# 3   2873212765  4/21/2016 11:59:59 PM   56.700001    125.002104   NaN
# 4   2873212765  5/12/2016 11:59:59 PM   57.299999    126.324875   NaN
# ..         ...                    ...         ...           ...   ...
# 62  8877689391    5/6/2016 6:43:35 AM   85.000000    187.392923   NaN
# 63  8877689391    5/8/2016 7:35:53 AM   85.400002    188.274775   NaN
# 64  8877689391    5/9/2016 6:39:44 AM   85.500000    188.495234   NaN
# 65  8877689391   5/11/2016 6:51:47 AM   85.400002    188.274775   NaN
# 66  8877689391   5/12/2016 6:42:53 AM   84.000000    185.188300   NaN
#
#           BMI  IsManualReport          LogId
# 0   22.650000            True  1462233599000
# ...

# %%
weight = weight.drop(columns = ['WeightKg' , 'Fat', 'LogId', 'IsManualReport', 'Date'])
weight = weight.groupby(by = ['Id']).mean()
weight = weight.reset_index()
weight
# Out:
#            Id  WeightPounds        BMI
# 0  1503960366    115.963147  22.650000
# 1  1927972279    294.317120  47.540001
# 2  2873212765    125.663489  21.570001
# 3  4319703577    159.504452  27.415000
# 4  4558609924    153.529918  27.214000
# 5  5577150313    199.959265  28.000000
# 6  6962181067    135.701872  24.028000
# 7  8877689391    187.714432  25.487083

# %%
activity = act.merge(weight, on = ['Id'], how = 'left')
activity
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    4/12/2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391     5/8/2016       10686       8.110000         8.110000
# 936  8877689391     5/9/2016       20226      18.250000        18.250000
# 937  8877689391    5/10/2016       10733       8.150000         8.150000
# 938  8877689391    5/11/2016       21420      19.559999        19.559999
# 939  8877689391    5/12/2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
step_id = activity.groupby(by = 'Id').mean()[['TotalSteps']]
step_id
# Out:
#               TotalSteps
# Id
# 1503960366  12116.741935
# 1624580081   5743.903226
# 1644430081   7282.966667
# 1844505072   2580.064516
# 1927972279    916.129032
# 2022484408  11370.645161
# 2026352035   5566.870968
# 2320127002   4716.870968
# 2347167796   9519.666667
# 2873212765   7555.774194
# 3372868164   6861.650000
# 3977333714  10984.566667
# 4020332650   2267.225806
# 4057192912   3838.000000
# 4319703577   7268.838710
# 4388161847  10813.935484
# 4445114986   4796.548387
# 4558609924   7685.129032
# 4702921684   8572.064516
# 5553957443   8612.580645
# 5577150313   8304.433333
# 6117666160   7046.714286
# 6290855005   5649.551724
# 6775888955   2519.692308
# 6962181067   9794.806452
# 7007744171  11323.423077
# 7086361926   9371.774194
# 8053475328  14763.290323
# 8253242879   6482.157895
# 8378563200   8717.709677
# 8583815059   7198.516129
# 8792009665   1853.724138
# 8877689391  16040.032258

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(data=activity, x = 'TotalSteps')
plt.title("Boxplot of total steps")
plt.show()

# %%
active_status = []
for s in step_id['TotalSteps']:
    if s < 7000:
        active_status.append('not active')
    elif s >= 7000 and s <= 10000:
        active_status.append('moderate active')
    elif s> 10000:
        active_status.append('very active')
step_id['ActiveStatus'] = active_status
step_id
# Out:
#               TotalSteps     ActiveStatus
# Id
# 1503960366  12116.741935      very active
# 1624580081   5743.903226       not active
# 1644430081   7282.966667  moderate active
# 1844505072   2580.064516       not active
# 1927972279    916.129032       not active
# 2022484408  11370.645161      very active
# 2026352035   5566.870968       not active
# 2320127002   4716.870968       not active
# 2347167796   9519.666667  moderate active
# 2873212765   7555.774194  moderate active
# 3372868164   6861.650000       not active
# 3977333714  10984.566667      very active
# 4020332650   2267.225806       not active
# 4057192912   3838.000000       not active
# 4319703577   7268.838710  moderate active
# 4388161847  10813.935484      very active
# 4445114986   4796.548387       not active
# 4558609924   7685.129032  moderate active
# 4702921684   8572.064516  moderate active
# 5553957443   8612.580645  moderate active
# 5577150313   8304.433333  moderate active
# ...

# %%
percent_active = step_id.groupby(by = ['ActiveStatus']).count()
percent_active = percent_active.rename(columns = {'TotalSteps': 'Count'})
percent_active['Total'] = np.sum(percent_active['Count'])
percent_active['% of Status'] = (percent_active['Count'] / percent_active['Total']) * 100
percent_active
# Out:
#                  Count  Total  % of Status
# ActiveStatus
# moderate active     13     33    39.393939
# not active          13     33    39.393939
# very active          7     33    21.212121

# %%
percent_active = percent_active.reset_index()
plt.pie(percent_active['% of Status'], labels = percent_active['ActiveStatus'])
plt.title('User Type by Active Status')
plt.show()

# %% [markdown]
# Most of the users are on lightly active status, so only 20% of users are following CDC Guideline.

# %%
activity['ActivityDate'] = pd.to_datetime(activity['ActivityDate'])
activity['Day'] = activity['ActivityDate'].dt.dayofweek
#activity['Day'] = activity['Day'].replace({0: 'Monday', 1: 'Tuesday', 2: 'Wednesday', 3: 'Thursday', 4: 'Friday', 5: 'Saturday', 6: 'Sunday'})
activity
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-04-12       13162       8.500000         8.500000
# 1    1503960366   2016-04-13       10735       6.970000         6.970000
# 2    1503960366   2016-04-14       10460       6.740000         6.740000
# 3    1503960366   2016-04-15        9762       6.280000         6.280000
# 4    1503960366   2016-04-16       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391   2016-05-08       10686       8.110000         8.110000
# 936  8877689391   2016-05-09       20226      18.250000        18.250000
# 937  8877689391   2016-05-10       10733       8.150000         8.150000
# 938  8877689391   2016-05-11       21420      19.559999        19.559999
# 939  8877689391   2016-05-12        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
day_act = activity.groupby(by = ['Day']).mean()
day_act = day_act[['TotalSteps', 'TotalDistance', 'Calories']]
day_act = day_act.reset_index()
day_act['Day'] = day_act['Day'].replace({0: 'Monday', 1: 'Tuesday', 2: 'Wednesday', 3: 'Thursday', 4: 'Friday', 5: 'Saturday', 6: 'Sunday'})
day_act
# Out:
#          Day   TotalSteps  TotalDistance     Calories
# 0     Monday  7780.866667       5.552917  2324.208333
# 1    Tuesday  8125.006579       5.832237  2356.013158
# 2  Wednesday  7559.373333       5.488333  2302.620000
# 3   Thursday  7405.836735       5.312245  2199.571429
# 4     Friday  7448.230159       5.309921  2331.785714
# 5   Saturday  8152.975806       5.854677  2354.967742
# 6     Sunday  6933.231405       5.027190  2263.000000

# %%
plt.bar(day_act['Day'], day_act['TotalSteps'])
plt.xticks(rotation = 30)
plt.xlabel("Day")
plt.ylabel("Average Steps")
plt.title("Average Steps by Day")
plt.show()

# %%
plt.bar(day_act['Day'], day_act['TotalDistance'])
plt.xticks(rotation = 30)
plt.xlabel("Day")
plt.ylabel("Average Distance")
plt.title("Average Distance by Day")
plt.show()

# %%
plt.bar(day_act['Day'], day_act['Calories'])
plt.xticks(rotation = 30)
plt.xlabel("Day")
plt.ylabel("Average Calories")
plt.title("Average Calories by Day")
plt.show()

# %% [markdown]
# Users tend to walk farther ditance on Tuesday and Saturday

# %%
activity
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366   2016-04-12       13162       8.500000         8.500000
# 1    1503960366   2016-04-13       10735       6.970000         6.970000
# 2    1503960366   2016-04-14       10460       6.740000         6.740000
# 3    1503960366   2016-04-15        9762       6.280000         6.280000
# 4    1503960366   2016-04-16       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391   2016-05-08       10686       8.110000         8.110000
# 936  8877689391   2016-05-09       20226      18.250000        18.250000
# 937  8877689391   2016-05-10       10733       8.150000         8.150000
# 938  8877689391   2016-05-11       21420      19.559999        19.559999
# 939  8877689391   2016-05-12        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
boxplot_min = activity[['VeryActiveMinutes', 'FairlyActiveMinutes', 'LightlyActiveMinutes']]
boxplot_min.plot(kind = 'box', title = 'Minutes Distribution by Active Status')
# Out:
# <AxesSubplot:title={'center':'Minutes Distribution by Active Status'}>

# %%
activity[['SedentaryMinutes']].boxplot()
# Out:
# <AxesSubplot:>

# %%
activity[['LightlyActiveMinutes']].boxplot()
# Out:
# <AxesSubplot:>

# %%
activity[['FairlyActiveMinutes']].boxplot()
# Out:
# <AxesSubplot:>

# %%
activity[['VeryActiveMinutes']].boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Most of the users spend their time seating or on inactive mode

# %%
activity.corr()
# Out:
#                                 Id  TotalSteps  TotalDistance  \
# Id                        1.000000    0.185721       0.241000
# TotalSteps                0.185721    1.000000       0.985369
# TotalDistance             0.241000    0.985369       1.000000
# TrackerDistance           0.238816    0.984822       0.999505
# LoggedActivitiesDistance  0.188015    0.181849       0.188332
# VeryActiveDistance        0.308691    0.740115       0.794582
# ModeratelyActiveDistance  0.026665    0.507105       0.470758
# LightActiveDistance       0.019629    0.692208       0.662002
# SedentaryActiveDistance  -0.015698    0.070505       0.082389
# VeryActiveMinutes         0.303608    0.667079       0.681297
# FairlyActiveMinutes       0.051158    0.498693       0.462899
# LightlyActiveMinutes     -0.098754    0.569600       0.516300
# SedentaryMinutes         -0.043319   -0.327484      -0.288094
# Calories                  0.396671    0.591568       0.644962
# ...

# %% [markdown]
# Insights: Activity minutes has high correlation with the distance (the more active you are, the higher distance you reach)

# %%
sleep
# Out:
#              Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0    1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1    1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2    1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3    1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4    1503960366  4/17/2016 12:00:00 AM                  1                 700
# ..          ...                    ...                ...                 ...
# 408  8792009665  4/30/2016 12:00:00 AM                  1                 343
# 409  8792009665   5/1/2016 12:00:00 AM                  1                 503
# 410  8792009665   5/2/2016 12:00:00 AM                  1                 415
# 411  8792009665   5/3/2016 12:00:00 AM                  1                 516
# 412  8792009665   5/4/2016 12:00:00 AM                  1                 439
#
#      TotalTimeInBed
# ...

# %%
sleep['TotalMinutesNotSleep'] = sleep['TotalTimeInBed'] - sleep['TotalMinutesAsleep']
sleep['% of NotSleep'] = (sleep['TotalMinutesNotSleep'] / sleep['TotalTimeInBed']) * 100
sleep['Hours Sleep'] = sleep['TotalMinutesAsleep'] / 60
sleep
# Out:
#              Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0    1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1    1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2    1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3    1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4    1503960366  4/17/2016 12:00:00 AM                  1                 700
# ..          ...                    ...                ...                 ...
# 408  8792009665  4/30/2016 12:00:00 AM                  1                 343
# 409  8792009665   5/1/2016 12:00:00 AM                  1                 503
# 410  8792009665   5/2/2016 12:00:00 AM                  1                 415
# 411  8792009665   5/3/2016 12:00:00 AM                  1                 516
# 412  8792009665   5/4/2016 12:00:00 AM                  1                 439
#
# ...

# %%
sleep_id = sleep.groupby(by = 'Id').mean()[['Hours Sleep']]
sleep_id
# Out:
#             Hours Sleep
# Id
# 1503960366     6.004667
# 1644430081     4.900000
# 1844505072    10.866667
# 1927972279     6.950000
# 2026352035     8.436310
# 2320127002     1.016667
# 2347167796     7.446667
# 3977333714     4.894048
# 4020332650     5.822917
# 4319703577     7.944231
# 4388161847     6.718750
# 4445114986     6.419643
# 4558609924     2.126667
# 4702921684     7.019048
# 5553957443     7.724731
# 5577150313     7.200000
# 6117666160     7.979630
# 6775888955     5.827778
# 6962181067     7.466667
# 7007744171     1.141667
# 7086361926     7.552083
# 8053475328     4.950000
# 8378563200     7.389062
# 8792009665     7.261111

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(data=sleep, x = 'Hours Sleep')
plt.title("Boxplot of # of Hours Asleep")
plt.show()

# %%
sleep_status = []
for t in sleep_id['Hours Sleep']: 
    if t >= 7.0:
        sleep_status.append('Enough Sleep')
    else:
        sleep_status.append('Not Enough Sleep')
sleep_id['Sleep Status'] = sleep_status
sleep_id
# Out:
#             Hours Sleep      Sleep Status
# Id
# 1503960366     6.004667  Not Enough Sleep
# 1644430081     4.900000  Not Enough Sleep
# 1844505072    10.866667      Enough Sleep
# 1927972279     6.950000  Not Enough Sleep
# 2026352035     8.436310      Enough Sleep
# 2320127002     1.016667  Not Enough Sleep
# 2347167796     7.446667      Enough Sleep
# 3977333714     4.894048  Not Enough Sleep
# 4020332650     5.822917  Not Enough Sleep
# 4319703577     7.944231      Enough Sleep
# 4388161847     6.718750  Not Enough Sleep
# 4445114986     6.419643  Not Enough Sleep
# 4558609924     2.126667  Not Enough Sleep
# 4702921684     7.019048      Enough Sleep
# 5553957443     7.724731      Enough Sleep
# 5577150313     7.200000      Enough Sleep
# 6117666160     7.979630      Enough Sleep
# 6775888955     5.827778  Not Enough Sleep
# 6962181067     7.466667      Enough Sleep
# 7007744171     1.141667  Not Enough Sleep
# 7086361926     7.552083      Enough Sleep
# ...

# %%
sleep_id = sleep_id.reset_index()
percent_sleep = sleep_id.groupby(by = ['Sleep Status']).count()
percent_sleep = percent_sleep.rename(columns = {'Hours Sleep': 'Count'})
percent_sleep['Total'] = np.sum(percent_sleep['Count'])
percent_sleep['% of Status'] = (percent_sleep['Count'] / percent_sleep['Total']) * 100
percent_sleep
# Out:
#                   Id  Count  Total  % of Status
# Sleep Status
# Enough Sleep      12     12     24         50.0
# Not Enough Sleep  12     12     24         50.0

# %%
percent_sleep = percent_sleep.reset_index()
plt.pie(percent_sleep['% of Status'], labels = percent_sleep['Sleep Status'])
plt.title('User Type by Sleep Hours')
plt.show()

# %% [markdown]
# According to CDC guideline, people should sleep 7 hours or more. Based on our data, only 50% of users sleep 7 ours or more.

# %%
sleep['SleepDay'] = pd.to_datetime(sleep['SleepDay'])
sleep['Day'] = sleep['SleepDay'].dt.dayofweek
sleep
# Out:
#              Id   SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0    1503960366 2016-04-12                  1                 327
# 1    1503960366 2016-04-13                  2                 384
# 2    1503960366 2016-04-15                  1                 412
# 3    1503960366 2016-04-16                  2                 340
# 4    1503960366 2016-04-17                  1                 700
# ..          ...        ...                ...                 ...
# 408  8792009665 2016-04-30                  1                 343
# 409  8792009665 2016-05-01                  1                 503
# 410  8792009665 2016-05-02                  1                 415
# 411  8792009665 2016-05-03                  1                 516
# 412  8792009665 2016-05-04                  1                 439
#
#      TotalTimeInBed  TotalMinutesNotSleep  % of NotSleep  Hours Sleep  Day
# 0               346                    19       5.491329     5.450000    1
# ...

# %%
sleep_day = sleep.groupby(by = 'Day').mean()[['Hours Sleep']]
sleep_day = sleep_day.reset_index()
sleep_day['Day'] = sleep_day['Day'].replace({0: 'Monday', 1: 'Tuesday', 2: 'Wednesday', 3: 'Thursday', 4: 'Friday', 5: 'Saturday', 6: 'Sunday'})
sleep_day
# Out:
#          Day  Hours Sleep
# 0     Monday     6.980496
# 1    Tuesday     6.742308
# 2  Wednesday     7.244697
# 3   Thursday     6.706154
# 4     Friday     6.757018
# 5   Saturday     7.013506
# 6     Sunday     7.545758

# %%
plt.bar(sleep_day['Day'], sleep_day['Hours Sleep'])
plt.xticks(rotation = 30)
plt.xlabel('Day')
plt.ylabel('# of Hours Sleep')
plt.title('Average # of Hours Sleep by Day')
# Out:
# Text(0.5, 1.0, 'Average # of Hours Sleep by Day')

# %% [markdown]
# People tend to sleep longer on Wednesday and Sunday, where users spend burn more calories the day before.

# %%
no_sleep = sleep.groupby(by = 'Day').mean()[['TotalMinutesNotSleep']]
no_sleep = no_sleep.reset_index()
no_sleep['Day'] = no_sleep['Day'].replace({0: 'Monday', 1: 'Tuesday', 2: 'Wednesday', 3: 'Thursday', 4: 'Friday', 5: 'Saturday', 6: 'Sunday'})
no_sleep
# Out:
#          Day  TotalMinutesNotSleep
# 0     Monday             37.340426
# 1    Tuesday             38.753846
# 2  Wednesday             35.348485
# 3   Thursday             33.430769
# 4     Friday             39.631579
# 5   Saturday             40.465517
# 6     Sunday             50.763636

# %%
plt.bar(no_sleep['Day'], no_sleep['TotalMinutesNotSleep'])
plt.xticks(rotation = 30)
plt.xlabel('Day')
plt.ylabel('# of Minutes Needed to be Spent to get Asleep')
plt.title('Average # of Minutes Needed to be Spent to get Asleep')
# Out:
# Text(0.5, 1.0, 'Average # of Minutes Needed to be Spent to get Asleep')

# %%
in_bed = sleep.groupby(by = 'Day').mean()[['TotalTimeInBed']]
in_bed = in_bed.reset_index()
in_bed['Day'] = in_bed['Day'].replace({0: 'Monday', 1: 'Tuesday', 2: 'Wednesday', 3: 'Thursday', 4: 'Friday', 5: 'Saturday', 6: 'Sunday'})
in_bed['Hours In Bed'] = in_bed['TotalTimeInBed'] / 60
in_bed
# Out:
#          Day  TotalTimeInBed  Hours In Bed
# 0     Monday      456.170213      7.602837
# 1    Tuesday      443.292308      7.388205
# 2  Wednesday      470.030303      7.833838
# 3   Thursday      435.800000      7.263333
# 4     Friday      445.052632      7.417544
# 5   Saturday      461.275862      7.687931
# 6     Sunday      503.509091      8.391818

# %%
plt.bar(in_bed['Day'], in_bed['Hours In Bed'])
plt.xticks(rotation = 30)
plt.xlabel('Day')
plt.ylabel('# of Hours In Bed')
plt.title('Average # of Hours In Bed')
# Out:
# Text(0.5, 1.0, 'Average # of Hours In Bed')

# %% [markdown]
# During the weekend, people spend longer time lying in bed, and thus spend longer time to get asleep

# %%
activity['VeryActiveMinutes'].mean()
# Out:
# 21.164893617021278
